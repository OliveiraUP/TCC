# %%
# Importa o pandas
import pandas as pd
import numpy as np

# %%
# Carrega o dataset de alunos. Informar o caminho do arquivo.
dados_aluno = pd.read_csv("TS_ALUNO_34EM_2021.csv", sep = ';')

# %%
# Shape (Quantidade de linhas e colunas)
dados_aluno.shape
# Out:
# (2288747, 106)

# %%
# Visualiza uma amostra dos dados
dados_aluno.head()
# Out:
#    ID_SAEB  ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_AREA  ID_ESCOLA  IN_PUBLICA  \
# 0     2021          1     11       6316600        2   61342611           1
# 1     2021          1     11       6316600        2   61342611           1
# 2     2021          1     11       6316600        2   61342611           1
# 3     2021          1     11       6316600        2   61342611           1
# 4     2021          1     11       6316600        2   61342611           1
#
#    ID_LOCALIZACAO  ID_TURMA  ID_SERIE  ...  TX_RESP_Q22  TX_RESP_Q23a  \
# 0               1   1252889        12  ...            B             D
# 1               1   1252889        12  ...            .             .
# 2               1   1252889        12  ...            .             .
# 3               1   1252889        12  ...            A             D
# 4               1   1252889        12  ...            .             *
#
#    TX_RESP_Q23b  TX_RESP_Q23c  TX_RESP_Q23d  TX_RESP_Q23e  TX_RESP_Q23f  \
# 0             D             .             D             D             D
# 1             .             .             .             .             .
# 2             .             .             .             .             .
# 3             D             D             A             B             C
# 4             D             D             .             D             B
#
#    TX_RESP_Q23g  TX_RESP_Q23h  TX_RESP_Q23i
# 0             .             .             D
# 1             .             .             .
# 2             .             .             .
# 3             C             C             A
# 4             D             D             D
#
# [5 rows x 106 columns]

# %%
#Mostra as colunas
dados_aluno.columns
# Out:
# Index(['ID_SAEB', 'ID_REGIAO', 'ID_UF', 'ID_MUNICIPIO', 'ID_AREA', 'ID_ESCOLA',
#        'IN_PUBLICA', 'ID_LOCALIZACAO', 'ID_TURMA', 'ID_SERIE',
#        ...
#        'TX_RESP_Q22', 'TX_RESP_Q23a', 'TX_RESP_Q23b', 'TX_RESP_Q23c',
#        'TX_RESP_Q23d', 'TX_RESP_Q23e', 'TX_RESP_Q23f', 'TX_RESP_Q23g',
#        'TX_RESP_Q23h', 'TX_RESP_Q23i'],
#       dtype='object', length=106)

# %%
# Filtra os dados pela coluna 'ID_UF' pelo código 53 que corresponde ao DF
filtro_uf = dados_aluno['ID_UF'] == 53

# Filtra os dados pela coluna 'IN_PREENCHIMENTO_LP' pelo código 1 que corresponde a um preenchimento verdadeiro da prova
filtro_preenchimento_LP = dados_aluno['IN_PREENCHIMENTO_LP'] == 1

# Filtra os dados pela coluna 'IN_PREENCHIMENTO_MT' pelo código 1 que corresponde a um preenchimento verdadeiro da prova
filtro_preenchimento_MT = dados_aluno['IN_PREENCHIMENTO_MT'] == 1

# Filtra os dados pela coluna 'IN_PREENCHIMENTO_QUESTIONARIO' pelo código 1 que corresponde a um preenchimento 
#verdadeiro do questionário
filtro_preench_quest = dados_aluno['IN_PREENCHIMENTO_QUESTIONARIO'] == 1

# Aplica ambos os filtros usando o operador lógico AND (&)
dados_aluno_df = dados_aluno[filtro_uf & filtro_preenchimento_LP & filtro_preenchimento_MT & filtro_preench_quest]

# %%
# Convertendo as colunas para strings e substituindo os pontos por vírgulas
colunas_para_substituir = ['PESO_ALUNO_LP', 'PESO_ALUNO_MT', 'PROFICIENCIA_LP', 'PROFICIENCIA_LP_SAEB',
                           'PROFICIENCIA_MT', 'PROFICIENCIA_MT_SAEB']
for coluna in colunas_para_substituir:
    dados_aluno_df[coluna] = dados_aluno_df[coluna].astype(str).str.replace('.', ',')
# Out:
# C:\Users\ferna\AppData\Local\Temp\ipykernel_19596\3636634898.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_aluno_df[coluna] = dados_aluno_df[coluna].astype(str).str.replace('.', ',')
# C:\Users\ferna\AppData\Local\Temp\ipykernel_19596\3636634898.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_aluno_df[coluna] = dados_aluno_df[coluna].astype(str).str.replace('.', ',')

# %%
#Aqui percebe-se que os dados já foram reduzidos
dados_aluno_df.shape
# Out:
# (17169, 106)

# %%
#o comando abaixo serve para testar os valores únicos que a coluna possui. Então basta informar o nome da coluna.
dados_aluno_df['PESO_ALUNO_LP'].unique()
# Out:
# array(['1,5833333333', '1,1111111111', '1,2857142857', '1,2121212121',
#        '1,1818181818', '1,0833333333', '1,1515151515', '1,0263157895',
#        '1,21875', '1,1481481481', '1,4482758621', '1,4', '3,125',
#        '4,1666666667', '2,5555555556', '3,2857142857', '23,0',
#        '3,8333333333', '3,25', '2,7777777778', '1,5714285714',
#        '1,3636363636', '1,4285714286', 'nan', '2,2222222222', '6,5',
#        '6,25', '1,4516129032', '1,6153846154', '5,75', '1,4666666667',
#        '1,8333333333', '1,72', '2,25', '2,6666666667', '16,258685195',
#        '1,6315789474', '1,3333333333', '1,0967741935', '1,1212121212',
#        '1,4615384615', '1,3571428571', '1,275862069', '1,44',
#        '1,0909090909', '1,15625', '1,6', '1,4074074074', '1,85',
#        '1,3703703704', '1,5217391304', '1,2592592593', '1,5384615385',
#        '1,5909090909', '1,2580645161', '1,1875', '1,3214285714', '1,52',
#        '10,839123463', '1,5652173913', '1,652173913', '1,2068965517',
#        '2,0714285714', '1,3181818182', '1,064516129', '1,25',
#        '0,9677419355', '1,0344827586', '0,9666666667', '1,0',
#        '1,1785714286', '1,7333333333', '1,0571428571', '1,1935483871',
#        '1,6842105263', '1,1290322581', '1,1612903226', '1,375',
#        '8,1293425975', '1,7', '3,1818181818', '2,9285714286', '4,125',
#        '2,2857142857', '5,0', '2,3846153846', '2,4285714286', '10,0',
#        '1,5', '1,28', '1,4166666667', '1,65', '1,2307692308',
#        '1,7894736842', '1,4583333333', '1,347826087', '1,36',
#        '13,548904329', '2,0', '2,4705882353', '2,2941176471',
#        '2,1666666667', '8,0', '3,5', '2,1875', '1,1315789474',
#        '1,4642857143', '1,1944444444', '1,4333333333', '1,1025641026',
#        '1,2', '1,1621621622', '2,1489361702', '1,3928571429',
#        '1,3666666667', '1,2413793103', '1,4814814815', '1,9375',
#        '1,9047619048', '1,7222222222', '2,1333333333', '2,0769230769',
#        '1,4210526316', '1,2173913043', '1,8666666667', '1,619047619',
#        '1,6111111111', '3,6102027469', '3,9298561151', '3,4096359276',
#        '3,5457348407', '5,8571428571', '9,4842330305', '2,8125', '2,875',
#        '2,7058823529', '3,2', '4,7142857143', '2,0952380952', '2,3',
#        '2,4210526316', '1,9565217391', '3,4615384615', '4,0', '3,0',
#        '1,5454545455', '1,7619047619', '1,7391304348', '1,1333333333',
#        '1,2666666667', '1,7826086957', '1,6363636364', '1,3548387097',
#        '1,2727272727', '1,75', '1,2083333333', '1,6470588235',
#        '1,5263157895', '5,4195617317', '2,0555555556', '1,8095238095',
#        '1,6086956522', '1,8421052632', '3,4545454545', '2,5',
#        '1,3793103448', '2,375', '3,875', '1,2258064516', '1,3', '2,125',
#        '1,1666666667', '1,8181818182', '1,3043478261', '1,6666666667',
#        '1,1071428571', '1,4347826087', '1,4782608696', '1,32',
#        '1,1142857143', '1,05', '1,1470588235', '2,1428571429', '2,6',
#        '4,625', '2,7142857143', '1,8823529412', '3,2307692308', '6,0',
#        '6,4', '1,0810810811', '1,4230769231', '1,3103448276', '1,125',
#        '1,3461538462', '1,1176470588', '1,0857142857', '1,2222222222',
#        '1,0555555556', '1,3125', '1,0882352941', '1,1388888889',
#        '1,1764705882', '1,1428571429', '1,4137931034', '2,1111111111',
#        '1,027027027', '1,8947368421', '1,2380952381', '4,25', '1,6875',
#        '1,7692307692', '2,8333333333', '1,9545454545', '1,5769230769',
#        '1,3225806452', '1,1351351351', '1,2962962963', '1,0487804878',
#        '1,1052631579', '1,1282051282', '1,1081081081', '1,0769230769',
#        '1,24', '1,1724137931', '1,4761904762', '0,875', '1,8', '1,625',
#        '1,7916666667', '1,64', '1,7368421053', '1,56', '2,5454545455',
#        '2,7272727273', '1,48', '1,45', '2,1538461538', '0,9523809524',
#        '1,0526315789', '2,1', '1,0540540541', '1,025', '2,4117647059',
#        '1,7727272727', '2,2352941176', '1,5416666667', '2,2666666667',
#        '1,3076923077', '2,6153846154', '1,5294117647', '1,9285714286',
#        '1,2333333333', '1,28125', '1,7272727273', '2,1739130435',
#        '1,8076923077', '1,2702702703', '1,3823529412', '1,1162790698',
#        '1,4242424242', '1,2972972973', '1,4117647059', '1,7407407407',
#        '1,3428571429', '1,0277777778', '1,04', '1,0588235294',
#        '1,0666666667', '1,253384913', '1,2202265819', '1,3551554828',
#        '1,2149669846', '1,4093617021', '1,4520696325', '1,2998065764',
#        '1,2964907433', '1,344508919', '1,3103569545', '1,2100580271',
#        '1,1365820178', '1,6818181818', '2,0833333333', '1,9230769231',
#        '2,8888888889', '1,4705882353', '1,0322580645', '1,4736842105',
#        '12,194013896', '3,4', '2,0588235294', '5,8', '2,3333333333',
#        '2,4666666667', '1,9444444444', '1,3684210526', '1,3529411765',
#        '1,35', '1,0789473684', '1,2058823529', '2,5333333333',
#        '1,0243902439', '1,3448275862', '1,2903225806', '3,7821171634',
#        '4,0447641886', '3,860911271', '6,0170045782', '1,875', '1,8125',
#        '1,3913043478', '3,5555555556', '2,5384615385', '4,5714285714',
#        '1,8235294118', '2,3571428571', '1,2424242424', '1,2352941176',
#        '1,1379310345', '1,0454545455', '1,7142857143', '4,5',
#        '1,2692307692', '1,1153846154', '1,4090909091', '1,9411764706',
#        '2,4166666667', '2,8', '3,625', '1,9333333333', '2,6363636364',
#        '3,1111111111', '1,55', '1,4545454545', '2,0625', '2,625',
#        '1,9090909091', '2,2777777778', '2,9375', '2,5882352941',
#        '1,5555555556', '1,8260869565', '1,303030303', '1,8888888889',
#        '2,5833333333', '2,1764705882', '1,2432432432', '1,2571428571',
#        '1,1304347826', '4,0614780903', '3,9110529758', '1,1538461538'],
#       dtype=object)

# %%
#Selecionar as colunas que são de interesse, para isso é necessário identificar as perguntas que são comuns aos
#5 questionários e que são pertinentes a análise
colunas = ['ID_SAEB', 'ID_ESCOLA', 'IN_PUBLICA', 'ID_LOCALIZACAO', 'ID_TURMA', 'ID_SERIE', 'ID_ALUNO', 
           'IN_SITUACAO_CENSO','IN_PREENCHIMENTO_LP', 'IN_PREENCHIMENTO_MT','PESO_ALUNO_LP', 'PESO_ALUNO_MT', 
           'PROFICIENCIA_LP', 'PROFICIENCIA_LP_SAEB', 'PROFICIENCIA_MT', 'PROFICIENCIA_MT_SAEB',
           'IN_PREENCHIMENTO_QUESTIONARIO', 'TX_RESP_Q04', 'TX_RESP_Q11e', 'TX_RESP_Q11a', 'TX_RESP_Q12g',
           'TX_RESP_Q11g', 'TX_RESP_Q11c', 'TX_RESP_Q11f', 
            'TX_RESP_Q11d', 'TX_RESP_Q06a', 'TX_RESP_Q07', 
           'TX_RESP_Q06b', 'TX_RESP_Q08', 'TX_RESP_Q09f','TX_RESP_Q20e', 
            'TX_RESP_Q20c', 'TX_RESP_Q18', 'TX_RESP_Q19', 'TX_RESP_Q09c', 
            'TX_RESP_Q09d', 'TX_RESP_Q09e', 'TX_RESP_Q09b', 'TX_RESP_Q20d','TX_RESP_Q12h']

#atribui somente as colunas desejadas ao dados_aluno_df inicial
dados_aluno_df = dados_aluno_df[colunas]

# %%
dados_aluno_df.head()
# Out:
#          ID_SAEB  ID_ESCOLA  IN_PUBLICA  ID_LOCALIZACAO  ID_TURMA  ID_SERIE  \
# 2257759     2021   61324396           1               1   1236039        12
# 2257760     2021   61324396           1               1   1236039        12
# 2257762     2021   61324396           1               1   1236039        12
# 2257763     2021   61324396           1               1   1236039        12
# 2257765     2021   61324396           1               1   1236039        12
#
#          ID_ALUNO  IN_SITUACAO_CENSO  IN_PREENCHIMENTO_LP  \
# 2257759  48880822                  1                    1
# 2257760  48880823                  1                    1
# 2257762  48880825                  1                    1
# 2257763  48880826                  1                    1
# 2257765  48880828                  1                    1
#
#          IN_PREENCHIMENTO_MT  ... TX_RESP_Q20e TX_RESP_Q20c TX_RESP_Q18  \
# 2257759                    1  ...            D            C           A
# 2257760                    1  ...            D            C           A
# 2257762                    1  ...            D            D           A
# 2257763                    1  ...            C            C           B
# 2257765                    1  ...            B            C           A
#
#         TX_RESP_Q19 TX_RESP_Q09c TX_RESP_Q09d  TX_RESP_Q09e TX_RESP_Q09b  \
# 2257759           A            C            B             C            B
# 2257760           A            C            B             C            B
# 2257762           A            B            B             C            A
# 2257763           A            C            C             C            B
# 2257765           A            C            C             C            B
#
#         TX_RESP_Q20d TX_RESP_Q12h
# 2257759            D            B
# 2257760            .            B
# 2257762            A            B
# 2257763            A            B
# 2257765            D            A
#
# [5 rows x 40 columns]

# %%
#substituir os valores da pergunta "Na sua casa tem freezer (parte da geladeira duplex)?" para sim e não
#sustituindo com sim
# Valores antigos que queremos substituir
#valores_antigos = ['B', 'C', 'D', 'E', 'A', '*', '.']

# Novo valor para substituição
#novo_valor = ['Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


#dados_aluno_df['TX_RESP_Q009'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
#dados_aluno_df['TX_RESP_Q009'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
#dados_aluno_df.loc[:, 'TX_RESP_Q009'] = dados_aluno_df['TX_RESP_Q009'].replace(valores_antigos, novo_valor)

#sustituindo com não
# Valores antigos que queremos substituir
#valores_antigos = ['A']
# Novo valor para substituição
#novo_valor = 'Não'
# Substituindo os valores antigos pelo novo valor na coluna 'A'
#dados_aluno_df.loc[:, 'TX_RESP_Q009'] = dados_aluno_df['TX_RESP_Q009'].replace(valores_antigos, novo_valor)

# %%
#substituir os valores da pergunta "Na sua casa tem freezer separado da geladeira?" para sim e não
#sustituindo com sim
# Valores antigos que queremos substituir
#valores_antigos = ['B', 'C', 'D', 'E', 'A', '*', '.']

# Novo valor para substituição
#novo_valor = ['Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


#dados_aluno_df['TX_RESP_Q010'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
#dados_aluno_df['TX_RESP_Q010'].fillna('Não respondeu/Não soube responder', inplace=True)

# Substituindo os valores antigos pelo novo valor na coluna 'A'
#dados_aluno_df.loc[:, 'TX_RESP_Q010'] = dados_aluno_df['TX_RESP_Q010'].replace(valores_antigos, novo_valor)

#sustituindo com não
# Valores antigos que queremos substituir
#valores_antigos = ['A']
# Novo valor para substituição
#novo_valor = 'Não'
# Substituindo os valores antigos pelo novo valor na coluna 'A'
#dados_aluno_df.loc[:, 'TX_RESP_Q010'] = dados_aluno_df['TX_RESP_Q010'].replace(valores_antigos, novo_valor)

# %%
# Função para verificar se pelo menos uma das duas colunas é 'sim'
#def verifica_sim(row):
#    if row['TX_RESP_Q010'] == 'Sim' or row['TX_RESP_Q009'] == 'Sim':
#        return 'Sim'
#    elif row['TX_RESP_Q010'] == 'Não' and row['TX_RESP_Q009'] == 'Não':
#        return 'Não'
#    else:
#        return 'Não respondeu/Não soube responder'

# Aplicando a função para criar a nova coluna 'Resultado'
#dados_aluno_df['Na sua casa tem: - Freezer (independente ou segunda porta da geladeira).'] = dados_aluno_df.apply(verifica_sim, axis=1)

# %%
#remover as colunas 'TX_RESP_Q010', 'TX_RESP_Q009', já que uma nova foi criada no lugar
#dados_aluno_df.drop(['TX_RESP_Q010', 'TX_RESP_Q009'], axis=1, inplace=True)

# %%
#Como você se considera?
#Mudança de Resposta: Respostas em Branco, "*"", "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', 'E', 'F' , '*', '.']

# Novo valor para substituição
novo_valor = ['Branco(a)',  'Preto(a)', 'Pardo(a)', 'Amarelo(a)', 'Indígena', 'Não quero declarar', 'Não respondeu/Não soube responder'
             ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q04'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q04'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q04'] = dados_aluno_df['TX_RESP_Q04'].replace(valores_antigos, novo_valor)

# %%
#Você mora com sua mãe?
#Mudança de Resposta: Respostas em Branco, "*", "." mudou para "Não respondeu/Não soube responder"

valores_antigos = ['A', 'B', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q06a'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q06a'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q06a'] = dados_aluno_df['TX_RESP_Q06a'].replace(valores_antigos, novo_valor)

# %%
#Você mora com seu pai?
#Mudança de Resposta: Respostas em Branco, "*", "." mudou para "Não respondeu/Não soube responder"

valores_antigos = ['A', 'B', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q06b'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q06b'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q06b'] = dados_aluno_df['TX_RESP_Q06b'].replace(valores_antigos, novo_valor)

# %%
#Até que série sua mãe, ou a mulher responsável por você, estudou?
#Mudança de Resposta: Respostas em Branco ou "*" ou "." mudou para "Não respondeu/Não soube responder"


valores_antigos = ['A', 'B', 'C', 'D', 'E', 'F' , '*', '.']

# Novo valor para substituição
novo_valor = ['Não completou o 5º ano do Ensino Fundamental', 'Ensino Fundamental, até o 5º ano', 
              'Ensino Fundamental completo', 'Ensino Médio completo', 
              'Ensino Superior completo (faculdade ou graduação)', 'Não sei',
              'Não respondeu/Não soube responder', 'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q07'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q07'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q07'] = dados_aluno_df['TX_RESP_Q07'].replace(valores_antigos, novo_valor)

# %%
#Até que série seu pai, ou o homem responsável por você, estudou?
#Mudança de Resposta: Respostas em Branco ou "*" ou "." mudou para "Não respondeu/Não soube responder"

valores_antigos = ['A', 'B', 'C', 'D', 'E', 'F' , '*', '.']

# Novo valor para substituição
novo_valor = ['Não completou o 5º ano do Ensino Fundamental', 'Ensino Fundamental, até o 5º ano', 
              'Ensino Fundamental completo', 'Ensino Médio completo', 
              'Ensino Superior completo (faculdade ou graduação)', 'Não sei',
              'Não respondeu/Não soube responder', 'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q08'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q08'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q08'] = dados_aluno_df['TX_RESP_Q08'].replace(valores_antigos, novo_valor)

# %%
#Seus pais ou responsáveis conversam com você sobre o que acontece na escola?
#Mudança de Resposta: "Sempre ou quase sempre." mudou para "Sim", "De vez em quando." mudou para "Sim",
#"Nunca ou quase nunca." mudou para "Não", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"


valores_antigos = ['A', 'B', 'C', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Sim', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q09b'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q09b'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q09b'] = dados_aluno_df['TX_RESP_Q09b'].replace(valores_antigos, novo_valor)

# %%
#Seus pais ou responsáveis incentivam você a estudar?
#Mudança de Resposta: "Sempre ou quase sempre." mudou para "Sim", "De vez em quando." mudou para "Sim",
#"Nunca ou quase nunca." mudou para "Não", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Sim', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q09c'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q09c'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q09c'] = dados_aluno_df['TX_RESP_Q09c'].replace(valores_antigos, novo_valor)

# %%
#Seus pais ou responsáveis incentivam você a fazer o dever de casa e/ou os trabalhos da escola?
#Mudança de Resposta: "Sempre ou quase sempre." mudou para "Sim", "De vez em quando." mudou para "Sim",
#"Nunca ou quase nunca." mudou para "Não", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Sim', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q09d'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q09d'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q09d'] = dados_aluno_df['TX_RESP_Q09d'].replace(valores_antigos, novo_valor)

# %%
#Seus pais ou responsáveis incentivam você a ir a escola e/ou não faltar às aulas?
#Mudança de Resposta: "Sempre ou quase sempre." mudou para "Sim", "De vez em quando." mudou para "Sim",
#"Nunca ou quase nunca." mudou para "Não", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Sim', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q09e'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q09e'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q09e'] = dados_aluno_df['TX_RESP_Q09e'].replace(valores_antigos, novo_valor)

# %%
#Com qual frequência seus pais, ou responsáveis por você, vão à reunião de pais?
#Mudança de Resposta: "Sempre ou quase sempre." mudou para "Sim", "De vez em quando." mudou para "Sim",
#"Nunca ou quase nunca." mudou para "Não", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Sim', 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q09f'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q09f'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q09f'] = dados_aluno_df['TX_RESP_Q09f'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem geladeira?
#Mudança de Resposta: "Nenhum" mudou para "Não", "1" mudou para "Sim, uma", "2" mudou para "Sim, duas",
#"3 ou mais." mudou para "Sim, três ou mais.", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, uma', 'Sim, duas' , 'Sim, três ou mais', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q11a'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q11a'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q11a'] = dados_aluno_df['TX_RESP_Q11a'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem computador?
#Mudança de Resposta: "Nenhum" mudou para "Não", "1" mudou para "Sim, um", "2" mudou para "Sim, dois",
#"3 ou mais." mudou para "Sim, três ou mais.", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, um', 'Sim, dois' , 'Sim, três ou mais',
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q11c'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q11c'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q11c'] = dados_aluno_df['TX_RESP_Q11c'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem quartos para dormir?
#Mudança de Resposta: "Nenhum" mudou para "Não", "1" mudou para "Sim, um", "2" mudou para "Sim, dois",
#"3 ou mais." mudou para "Sim, três ou mais.", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, um', 'Sim, dois' , 'Sim, três ou mais', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q11d'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q11d'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q11d'] = dados_aluno_df['TX_RESP_Q11d'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem televisão em cores?
#Mudança de Resposta: "Nenhum" mudou para "Não", "1" mudou para "Sim, uma", "2" mudou para "Sim, duas",
#"3 ou mais." mudou para "Sim, três ou mais.", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, uma', 'Sim, duas' , 'Sim, três ou mais', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q11e'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q11e'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q11e'] = dados_aluno_df['TX_RESP_Q11e'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem banheiro?
#Mudança de Resposta: "Nenhum" mudou para "Não", "1" mudou para "Sim, um", "2" mudou para "Sim, dois",
#"3 ou mais." mudou para "Sim, três ou mais.", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, um', 'Sim, dois' , 'Sim, três ou mais', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q11f'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q11f'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q11f'] = dados_aluno_df['TX_RESP_Q11f'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem carro?
#Mudança de Resposta: "Nenhum" mudou para "Não", "1" mudou para "Sim, um", "2" mudou para "Sim, dois",
#"3 ou mais." mudou para "Sim, três ou mais.", Além disso Respostas em Branco, "*", "." mudou para 
#"Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, um', 'Sim, dois' , 'Sim, três ou mais', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q11g'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q11g'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q11g'] = dados_aluno_df['TX_RESP_Q11g'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem máquina de lavar roupa (O tanquinho NÃO deve ser considerado)?
#Mudança de Resposta: Respostas em Branco, "*", "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q12g'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q12g'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q12g'] = dados_aluno_df['TX_RESP_Q12g'].replace(valores_antigos, novo_valor)

# %%
#Você já abandonou a escola durante o período de aulas e ficou fora da escola o resto do ano?
#Mudança de Resposta:  em Branco, "*", "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, uma vez', 'Sim, duas vezes ou mais' , 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q19'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q19'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q19'] = dados_aluno_df['TX_RESP_Q19'].replace(valores_antigos, novo_valor)

# %%
#Você já foi reprovado?
#Mudança de Resposta:  em Branco, "*", "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim, uma vez', 'Sim, duas vezes ou mais' , 'Não respondeu/Não soube responder' ,'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q18'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q18'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q18'] = dados_aluno_df['TX_RESP_Q18'].replace(valores_antigos, novo_valor)

# %%
#Em dia de aula, quanto tempo você gasta assistindo à TV, navegando na internet ou jogando jogos eletrônicos?
#Mudança de Resposta: Respostas em Branco ou "*" ou "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não uso meu tempo para isso', 'Menos de 1 hora', 'Entre 1 e 2 horas', 
              'Mais de 2 horas', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q20e'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q20e'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q20e'] = dados_aluno_df['TX_RESP_Q20e'].replace(valores_antigos, novo_valor)

# %%
#Em dias de aula, quanto tempo você gasta fazendo trabalhos domésticos (ex.: lavando louça, limpando o quintal etc.)?
#Mudança de Resposta: Respostas em Branco ou "*" ou "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não uso meu tempo para isso', 'Menos de 1 hora', 'Entre 1 e 2 horas', 
              'Mais de 2 horas', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q20c'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q20c'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q20c'] = dados_aluno_df['TX_RESP_Q20c'].replace(valores_antigos, novo_valor)

# %%
#Atualmente você trabalha fora de casa (recebendo ou não um salário)?
#Mudança de Resposta: Respostas em Branco ou "*" ou "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', 'C', 'D', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Sim','Sim', 
              'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q20d'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q20d'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q20d'] = dados_aluno_df['TX_RESP_Q20d'].replace(valores_antigos, novo_valor)

# %%
#Na sua casa tem: - Freezer (independente ou segunda porta da geladeira).
#Mudança de Resposta: Respostas em Branco, "*", "." mudou para "Não respondeu/Não soube responder"
valores_antigos = ['A', 'B', '*', '.']

# Novo valor para substituição
novo_valor = ['Não', 'Sim', 'Não respondeu/Não soube responder',
              'Não respondeu/Não soube responder']


dados_aluno_df['TX_RESP_Q12h'].replace('nan', np.nan, inplace=True)

# Substituindo os valores nulos ou 'nan' pelo novo valor desejado
dados_aluno_df['TX_RESP_Q12h'].fillna('Não respondeu/Não soube responder', inplace=True)


# Substituindo os valores antigos pelo novo valor na coluna 'A'
dados_aluno_df.loc[:, 'TX_RESP_Q12h'] = dados_aluno_df['TX_RESP_Q12h'].replace(valores_antigos, novo_valor)

# %%
#Renomeia as perguntas do questionário de aluno

# Vetores com os nomes atuais e futuros das colunas
nomes_atuais = ['ID_SAEB', 'TX_RESP_Q04', 'TX_RESP_Q06a', 'TX_RESP_Q06b', 'TX_RESP_Q07', 
                'TX_RESP_Q08', 'TX_RESP_Q09b', 'TX_RESP_Q09c', 'TX_RESP_Q09d',  'TX_RESP_Q09e',   
                'TX_RESP_Q09f', 'TX_RESP_Q11a','TX_RESP_Q11c', 'TX_RESP_Q11d', 
                'TX_RESP_Q11e', 'TX_RESP_Q11f', 'TX_RESP_Q11g', 'TX_RESP_Q12g', 'TX_RESP_Q18',
                'TX_RESP_Q19',  'TX_RESP_Q20e', 'TX_RESP_Q20c','TX_RESP_Q20d', 'TX_RESP_Q12h']

nomes_futuros = ['ID_PROVA_BRASIL',
'Qual é a sua cor ou raça?', 
'Normalmente, quem mora na sua casa? - Mãe (mães ou madrasta).', 
'Normalmente, quem mora na sua casa? - Pai (pais ou padrasto).', 
'Qual é a maior escolaridade da sua mãe (ou mulher responsável por você)?', 
'Qual é a maior escolaridade de seu pai (ou homem responsável por você)?', 
'Seus pais ou responsáveis conversam com você sobre o que acontece na escola?', 
'Seus pais ou responsáveis incentivam você a estudar?', 
'Seus pais ou responsáveis incentivam você a fazer o dever de casa e/ou os trabalhos da escola?', 
'Seus pais ou responsáveis incentivam você a ir a escola e/ou não faltar às aulas?', 
'Seus pais ou responsáveis vão à reunião de pais?', 
'Na sua casa tem geladeira?', 
'Na sua casa tem computador?', 
'Na sua casa tem quartos para dormir?', 
'Na sua casa tem televisão?', 
'Na sua casa tem banheiro?', 
'Na sua casa tem carro?', 
'Na sua casa tem máquina de lavar roupa?',  
'Você já foi reprovado(a)?', 
'Alguma vez você abandonou a escola deixando de frequentá-la até o final do ano escolar?', 
'Fora da escola em dias de aula, quanto tempo você usa para: - Lazer (TV, internet, brincar, música etc.).', 
'Fora da escola em dias de aula, quanto tempo você usa para: - Trabalhar em casa (lavar louça, limpar quintal, cuidar dos irmãos).', 
'Atualmente você trabalha fora de casa (recebendo ou não um salário)?',
'Na sua casa tem: - Freezer (independente ou segunda porta da geladeira)'
]

# Renomeando as colunas usando os vetores
novos_nomes = dict(zip(nomes_atuais, nomes_futuros))
dados_aluno_df.rename(columns=novos_nomes, inplace=True)

# %%
#Salvar o dataframe gerado em um arquivo
dados_aluno_df.to_csv('dados_aluno_34anoEM_2021.csv', index=False)

# %%
dados_aluno_df.shape
# Out:
# (17169, 40)

# %%
dados_aluno_df.head()
# Out:
#          ID_PROVA_BRASIL  ID_ESCOLA  IN_PUBLICA  ID_LOCALIZACAO  ID_TURMA  \
# 2257759             2021   61324396           1               1   1236039
# 2257760             2021   61324396           1               1   1236039
# 2257762             2021   61324396           1               1   1236039
# 2257763             2021   61324396           1               1   1236039
# 2257765             2021   61324396           1               1   1236039
#
#          ID_SERIE  ID_ALUNO  IN_SITUACAO_CENSO  IN_PREENCHIMENTO_LP  \
# 2257759        12  48880822                  1                    1
# 2257760        12  48880823                  1                    1
# 2257762        12  48880825                  1                    1
# 2257763        12  48880826                  1                    1
# 2257765        12  48880828                  1                    1
#
#          IN_PREENCHIMENTO_MT  ...  \
# 2257759                    1  ...
# 2257760                    1  ...
# 2257762                    1  ...
# 2257763                    1  ...
# 2257765                    1  ...
#
#         Fora da escola em dias de aula, quanto tempo você usa para: - Lazer (TV, internet, brincar, música etc.).  \
# 2257759                                    Mais de 2 horas
# 2257760                                    Mais de 2 horas
# 2257762                                    Mais de 2 horas
# 2257763                                  Entre 1 e 2 horas
# 2257765                                    Menos de 1 hora
#
#         Fora da escola em dias de aula, quanto tempo você usa para: - Trabalhar em casa (lavar louça, limpar quintal, cuidar dos irmãos).  \
# 2257759                                  Entre 1 e 2 horas
# 2257760                                  Entre 1 e 2 horas
# 2257762                                    Mais de 2 horas
# 2257763                                  Entre 1 e 2 horas
# 2257765                                  Entre 1 e 2 horas
#
#         Você já foi reprovado(a)?  \
# 2257759                       Não
# 2257760                       Não
# 2257762                       Não
# 2257763              Sim, uma vez
# 2257765                       Não
#
#         Alguma vez você abandonou a escola deixando de frequentá-la até o final do ano escolar?  \
# 2257759                                                Não
# 2257760                                                Não
# 2257762                                                Não
# 2257763                                                Não
# 2257765                                                Não
#
#         Seus pais ou responsáveis incentivam você a estudar?  \
# 2257759                                                Sim
# 2257760                                                Sim
# 2257762                                                Sim
# 2257763                                                Sim
# 2257765                                                Sim
#
#         Seus pais ou responsáveis incentivam você a fazer o dever de casa e/ou os trabalhos da escola?  \
# 2257759                                                Sim
# 2257760                                                Sim
# 2257762                                                Sim
# 2257763                                                Sim
# 2257765                                                Sim
#
#          Seus pais ou responsáveis incentivam você a ir a escola e/ou não faltar às aulas?  \
# 2257759                                                Sim
# 2257760                                                Sim
# 2257762                                                Sim
# 2257763                                                Sim
# 2257765                                                Sim
#
#         Seus pais ou responsáveis conversam com você sobre o que acontece na escola?  \
# 2257759                                                Sim
# 2257760                                                Sim
# 2257762                                                Não
# 2257763                                                Sim
# 2257765                                                Sim
#
#         Atualmente você trabalha fora de casa (recebendo ou não um salário)?  \
# 2257759                                                Sim
# 2257760                  Não respondeu/Não soube responder
# 2257762                                                Não
# 2257763                                                Não
# 2257765                                                Sim
#
#         Na sua casa tem: - Freezer (independente ou segunda porta da geladeira)
# 2257759                                                Sim
# 2257760                                                Sim
# 2257762                                                Sim
# 2257763                                                Sim
# 2257765                                                Não
#
# [5 rows x 40 columns]
